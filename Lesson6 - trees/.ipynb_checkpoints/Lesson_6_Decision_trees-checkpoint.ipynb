# %% [markdown]
# # Решающие деревья

# %% [markdown]
# ### Вспомним линейные модели
#
# 1) Какие линейные модели мы прошли?
# 2) Какие у линейных моделей преимущества? Какие недостатки?

# %% [markdown]
# ### Что такое решающие деревья?![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.33.27.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.33.27.png)
#
# ### Пример с Титаником

# %% [markdown]
# ## Решающие деревья в задаче классификации
# Задача классификации с двумя признаками и тремя классами
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.37.01.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.37.01.png)

# %% [markdown]
# ## Решающие деревья в задаче регрессии
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.38.46.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.38.46.png)
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.39.07.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-02-25%20%D0%B2%2011.39.07.png)

# %% [markdown]
# # Примеры

# %%
# Датасет ирисов
from sklearn.datasets import load_iris # загружаем библиотеку с датасетом
from sklearn import tree # загружаем библиотеку для построения модели решающего дерева
iris = load_iris() # загружаем данные
clf = tree.DecisionTreeClassifier() # задаем модель, которую будем использовать
X = iris.data # Признаки
y = iris.target # Целевая переменная
clf = clf.fit(X, y) # обучаем модель на данных
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
# Датасет Титаник
import pandas as pd
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_train.loc[data_train.Sex == 'male','Sex'] = 1
data_train.loc[data_train.Sex == 'female','Sex'] = 2

data_train.loc[data_train.Embarked == 'S','Embarked'] = 1
data_train.loc[data_train.Embarked == 'C','Embarked'] = 2
data_train.loc[data_train.Embarked == 'Q','Embarked'] = 3

data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   2  38.0      1      0
# 2                             Heikkinen, Miss. Laina   2  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   2  35.0      1      0
# 4                           Allen, Mr. William Henry   1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        1
# 1          PC 17599  71.2833   C85        2
# 2  STON/O2. 3101282   7.9250   NaN        1
# 3            113803  53.1000  C123        1
# 4            373450   8.0500   NaN        1

# %%
data_test.loc[data_test.Sex == 'male','Sex'] = 1
data_test.loc[data_test.Sex == 'female','Sex'] = 2

data_test.loc[data_test.Embarked == 'S','Embarked'] = 1
data_test.loc[data_test.Embarked == 'C','Embarked'] = 2
data_test.loc[data_test.Embarked == 'Q','Embarked'] = 3

data_test.head()
# Out:
#    PassengerId  Pclass                                          Name Sex  \
# 0          892       3                              Kelly, Mr. James   1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)   2
# 2          894       2                     Myles, Mr. Thomas Francis   1
# 3          895       3                              Wirz, Mr. Albert   1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   2
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        3
# 1  47.0      1      0   363272   7.0000   NaN        1
# 2  62.0      0      0   240276   9.6875   NaN        3
# 3  27.0      0      0   315154   8.6625   NaN        1
# 4  22.0      1      1  3101298  12.2875   NaN        1

# %%
data_train.loc[data_train.Age.isnull(),'Age'] = data_train['Age'].median()
data_train.loc[data_train.Fare.isnull(),'Fare'] = data_train['Fare'].median()

data_test.loc[data_test.Age.isnull(),'Age'] = data_test['Age'].median()
data_test.loc[data_test.Fare.isnull(),'Fare'] = data_test['Fare'].median()

# %%
X = data_train.ix[:, [2, 4, 5, 6, 7, 9]].values
y = data_train.ix[:, 1]
# Out:
# /Users/o.lomakina/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
clf = tree.DecisionTreeClassifier() # задаем модель, которую будем использовать
clf = clf.fit(X, y) # обучаем модель на данных
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
# Делаем предсказания для тестовой выборки
X_test = data_test.ix[:, [1, 3, 4, 5, 6, 8]].values
y_test = clf.predict(X_test)

# %%
# Записываем предсказания в файл
with open('prediction.txt', 'w') as f:
    for i in y_test:
        f.write(str(i) + '\n')

# %% [markdown]
# # Случайный лес

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Обучаем модель
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)

# %%
# Делаем предсказания для тестовой выборки
y_test = clf.predict(X_test)

# %%
# Записываем предсказания в файл
with open('prediction.txt', 'w') as f:
    for i in y_test:
        f.write(str(i) + '\n')

# %% [markdown]
# # Кросс-валидация и перебор параметров

# %%
# Оценка качества работы модели на кросс-валидации
from sklearn.model_selection import cross_val_score
print(cross_val_score(clf, X, y))
print(cross_val_score(clf, X, y).mean())
# Out:
# [ 0.78787879  0.8047138   0.78451178]
# 0.792368125701

# %%
# Перебор параметров с помощью GridSearch
from sklearn.model_selection import GridSearchCV
parameters = {'max_depth':[2,3,4,5], 'min_samples_leaf':[1, 2, 5, 8], 'n_estimators': [10, 100, 1000]}
rf = RandomForestClassifier()
clf = GridSearchCV(rf, parameters)
clf.fit(X, y)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'max_depth': [2, 3, 4, 5], 'min_samples_leaf': [1, 2, 5, 8], 'n_estimators': [10, 100, 1000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print('Лучшая точность модели: ', clf.best_score_)
print('Параметры, при которых достигается лучшая точность: ', clf.best_params_)
# Out:
# Лучшая точность модели:  0.829405162738
# Параметры, при которых достигается лучшая точность:  {'max_depth': 4, 'min_samples_leaf': 2, 'n_estimators': 10}
